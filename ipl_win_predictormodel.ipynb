# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanush2915/iplmodel/blob/main/ipl_win_predictormodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os import read
import pandas as pd
matches=pd.read_csv('/content/drive/MyDrive/matches.csv')
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
import pandas as pd
deliveries=pd.read_csv('/content/drive/MyDrive/deliveries.csv')
deliveries
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
deliveries.shape
# Out:
# (260920, 17)

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
total_score=deliveries.groupby(["match_id","inning"]).sum()["total_runs"].reset_index()

# %%
total_score=total_score[total_score["inning"]==1]

# %%
total_score
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
 matches_df = matches.merge(total_score[["match_id",'total_runs']],left_on="id",right_on="match_id")

# %%
matches_df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# ...

# %%
matches_df["team1"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [ 'Mumbai Indians', 'Kolkata Knight Riders',
       'Rajasthan Royals', 'Chennai Super Kings',
        'Sunrisers Hyderabad',
        'Delhi Capitals', 'Punjab Kings',
       'Lucknow Super Giants', 'Gujarat Titans',
       'Royal Challengers Bengaluru']

# %%
matches_df["team1"]=matches_df["team1"].str.replace("Delhi Daredevils","Delhi Capitals") #changing names
matches_df["team2"]=matches_df["team2"].str.replace("Delhi Daredevils","Delhi Capitals")
matches_df["team1"]=matches_df["team1"].str.replace("Deccan Chargers","Sunrisers Hyderabad")
matches_df["team2"]=matches_df["team2"].str.replace("Deccan Chargers","Sunrisers Hyderabad")
matches_df["team1"]=matches_df["team1"].str.replace("Royal Challengers Bangalore","Royal Challengers Bengaluru")
matches_df["team2"]=matches_df["team2"].str.replace("Royal Challengers Bangalore","Royal Challengers Bengaluru")

# %%
matches_df=matches_df[matches_df["team1"].isin(teams)]
matches_df=matches_df[matches_df["team2"].isin(teams)]

# %%
matches_df.shape
# Out:
# (805, 22)

# %%
matches_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %%
matches_df=matches_df[["match_id","city","winner","total_runs"]]

# %%
matches_df.head()
# Out:
#    match_id       city                       winner  total_runs
# 0    335982  Bangalore        Kolkata Knight Riders         222
# 2    335984      Delhi             Delhi Daredevils         129
# 3    335985     Mumbai  Royal Challengers Bangalore         165
# 4    335986    Kolkata        Kolkata Knight Riders         110
# 6    335988  Hyderabad             Delhi Daredevils         142

# %%
delivery_df = matches_df.merge(deliveries,on="match_id")

# %%
delivery_df.head()
# Out:
#    match_id       city                 winner  total_runs_x  inning  \
# 0    335982  Bangalore  Kolkata Knight Riders           222       1
# 1    335982  Bangalore  Kolkata Knight Riders           222       1
# 2    335982  Bangalore  Kolkata Knight Riders           222       1
# 3    335982  Bangalore  Kolkata Knight Riders           222       1
# 4    335982  Bangalore  Kolkata Knight Riders           222       1
#
#             batting_team                 bowling_team  over  ball  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4  Kolkata Knight Riders  Royal Challengers Bangalore     0     5
#
#         batter   bowler  non_striker  batsman_runs  extra_runs  total_runs_y  \
# 0   SC Ganguly  P Kumar  BB McCullum             0           1             1
# ...

# %%
delivery_df= delivery_df[delivery_df["inning"]==2]

# %%
delivery_df.shape
# Out:
# (92663, 20)

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
delivery_df["total_runs_y"] = delivery_df["total_runs_y"].astype(int)

# %%
delivery_df.groupby(["match_id"])["total_runs_y"].cumsum()
# Out:
# 124         1
# 125         2
# 126         2
# 127         3
# 128         4
#          ...
# 192237    110
# 192238    111
# 192239    112
# 192240    113
# 192241    114
# Name: total_runs_y, Length: 92663, dtype: int64

# %%
delivery_df["current_score"]=delivery_df.groupby(["match_id"])["total_runs_y"].cumsum()

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... non_striker batsman_runs  extra_runs  total_runs_y  extras_type  \
# ...

# %%
delivery_df["runs_left"]= delivery_df["total_runs_x"]-delivery_df["current_score"]

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... batsman_runs extra_runs  total_runs_y  extras_type  is_wicket  \
# ...

# %%
delivery_df["balls_left"]=120-(delivery_df["over"]*6+delivery_df["ball"])

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs_y', 'extras_type',
#        'is_wicket', 'player_dismissed', 'dismissal_kind', 'fielder',
#        'current_score', 'runs_left', 'balls_left'],
#       dtype='object')

# %%
delivery_df["is_wicket"].dtype
# Out:
# dtype('int64')

# %%
delivery_df["wickets_left"]= 10 - delivery_df.groupby(["match_id"])["is_wicket"].cumsum()

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs_y extras_type  is_wicket  player_dismissed  \
# ...

# %%
delivery_df["crr"]= (delivery_df["current_score"]/(120-delivery_df["balls_left"]))*6 #curreentrunrate

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
delivery_df["rr"]= (delivery_df["runs_left"]/(delivery_df["balls_left"]))*6 #required runrate

# %%
def result (row):
    return 1 if row["batting_team"]==row["winner"] else 0

# %%
delivery_df["result"]=delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 192237   1426312    Chennai  Kolkata Knight Riders           113       2
# 192238   1426312    Chennai  Kolkata Knight Riders           113       2
# 192239   1426312    Chennai  Kolkata Knight Riders           113       2
# 192240   1426312    Chennai  Kolkata Knight Riders           113       2
# 192241   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
final_df= delivery_df[["batting_team","bowling_team","city","runs_left","balls_left","wickets_left","total_runs_x","crr","rr","result"]]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#                        batting_team           bowling_team       city  \
# 39113                Mumbai Indians  Kolkata Knight Riders     Mumbai
# 172422               Mumbai Indians   Lucknow Super Giants    Lucknow
# 114519          Chennai Super Kings       Rajasthan Royals        NaN
# 90547              Delhi Daredevils         Mumbai Indians      Delhi
# 145161             Rajasthan Royals         Gujarat Titans     Mumbai
# ...                             ...                    ...        ...
# 143630  Royal Challengers Bangalore         Mumbai Indians       Pune
# 72965              Rajasthan Royals         Mumbai Indians  Ahmedabad
# 39618   Royal Challengers Bangalore    Chennai Super Kings    Chennai
# 126832          Chennai Super Kings           Punjab Kings     Mumbai
# ...

# %%
final_df.dropna(inplace=True) #Dropping null values

# %%
final_df=final_df[final_df["balls_left"]!=0] #Removing rows where balls left is equal to zero since that will lead to inf value error , as we were dividing using it while calculating crr and rrr .

# %%
from sklearn.model_selection import train_test_split
X = final_df.iloc[:,:-1]
y= final_df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team         city  \
# 150984                 Punjab Kings               Gujarat Titans  Navi Mumbai
# 39182                Mumbai Indians        Kolkata Knight Riders       Mumbai
# 71098                Mumbai Indians             Rajasthan Royals       Mumbai
# 84515         Kolkata Knight Riders  Royal Challengers Bangalore    Bangalore
# 45794                Mumbai Indians          Chennai Super Kings       Mumbai
# ...                             ...                          ...          ...
# 11069   Royal Challengers Bangalore              Deccan Chargers    Cape Town
# 152206        Kolkata Knight Riders         Lucknow Super Giants         Pune
# 155554  Royal Challengers Bangalore               Gujarat Titans       Mumbai
# 104044  Royal Challengers Bangalore               Mumbai Indians    Bengaluru
# 20988         Kolkata Knight Riders  Royal Challengers Bangalore      Kolkata
#
# ...

# %%
y_train
# Out:
# 150984    1
# 39182     1
# 71098     1
# 84515     1
# 45794     1
#          ..
# 11069     0
# 152206    0
# 155554    1
# 104044    0
# 20988     1
# Name: result, Length: 70308, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
onehotencoder = ColumnTransformer([("onehotencoder",OneHotEncoder(sparse= False , drop="first"),["batting_team","bowling_team","city"])],remainder="passthrough")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline(steps=[
    ("step1",onehotencoder),
    ("step2",LogisticRegression(solver="liblinear"))])
pipe.fit(X_train  , y_train )
y_pred = pipe.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8117426181942311

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

pipe_rf = Pipeline(steps=[
    ("step1", onehotencoder),
    ("step2", RandomForestClassifier())
])

pipe_rf.fit(X_train, y_train)
y_pred_rf = pipe_rf.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.9989759344598055

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

pipe_dt = Pipeline(steps=[
    ("step1", onehotencoder),
    ("step2", DecisionTreeClassifier())
])

pipe_dt.fit(X_train, y_train)
y_pred_dt = pipe_dt.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.9904989474881948

# %%
teams
# Out:
# ['Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Punjab Kings',
#  'Lucknow Super Giants',
#  'Gujarat Titans',
#  'Royal Challengers Bengaluru']

# %%
delivery_df["city"].unique()
# Out:
# array(['Bangalore', 'Delhi', 'Mumbai', 'Kolkata', 'Hyderabad', 'Chennai',
#        'Jaipur', 'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Visakhapatnam', 'Pune',
#        'Raipur', 'Ranchi', 'Abu Dhabi', nan, 'Bengaluru', 'Dubai',
#        'Sharjah', 'Navi Mumbai', 'Chandigarh', 'Lucknow', 'Guwahati',
#        'Dharamsala', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe, open("pipe.pkl",'wb'))

# %%
# !pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 69.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.1 MB/s eta 0:00:00

# %%
# %%writefile app.py
'''import pandas as pd
import streamlit as st
import pickle
import matplotlib.pyplot as plt
teams=['Mumbai Indians',
 'Kolkata Knight Riders',
 'Rajasthan Royals',
 'Chennai Super Kings',
 'Sunrisers Hyderabad',
 'Delhi Capitals',
 'Punjab Kings',
 'Lucknow Super Giants',
 'Gujarat Titans',
 'Royal Challengers Bengaluru']

venue=['Bangalore', 'Delhi', 'Mumbai', 'Kolkata', 'Hyderabad', 'Chennai',
       'Jaipur', 'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
       'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
       'Ahmedabad', 'Cuttack', 'Nagpur', 'Visakhapatnam', 'Pune',
       'Raipur', 'Ranchi', 'Abu Dhabi', 'Bengaluru', 'Dubai',
       'Sharjah', 'Navi Mumbai', 'Chandigarh', 'Lucknow', 'Guwahati',
       'Dharamsala', 'Mohali']
pipe = pickle.load(open('pipe.pkl', 'rb'))
st.title('IPL Win Predictor')
col1, col2 = st.columns(2)

with col1:
    batting_team = st.selectbox('Select the Batting Team', sorted(teams))

with col2:
    bowling_team = st.selectbox('Select the Bowling Team', sorted(teams))

selectedvenue = st.selectbox('Select the Venue', sorted(venue))

target=st.number_input('Target')
col3,col4,col5=st.columns(3)
with col3:
  score=st.number_input('Score')
with col4:
  overs=st.number_input('Overs completed')
with col5:
  wickets=st.number_input('Wickets out')
if st.button('Predict'):
  runs_left=target-score
  balls_left=120-(overs*6)
  wickets=10-wickets
  crr=score/overs
  rr=(runs_left*6)/balls_left

  input_df=pd.DataFrame({'batting_team':[batting_team],'bowling_team':[bowling_team],'city':[selectedvenue],'runs_left':[runs_left],'balls_left':[balls_left],'wickets_left':[wickets],'total_runs_x':[target],'crr':[crr],'rr':[rr]})
  result=pipe.predict_proba(input_df)
  loss=result[0][0]
  win=result[0][1]
  st.header(batting_team + " _"+str(round(win*100))+"%")
  st.header(bowling_team + " _"+str(round(loss*100))+"%")'''

import pandas as pd
import streamlit as st
import pickle
import matplotlib.pyplot as plt

# Load the trained model (pipe.pkl)
pipe = pickle.load(open('pipe.pkl', 'rb'))

# Teams and Venues
teams = [
    'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
    'Chennai Super Kings', 'Sunrisers Hyderabad', 'Delhi Capitals',
    'Punjab Kings', 'Lucknow Super Giants', 'Gujarat Titans',
    'Royal Challengers Bengaluru'
]

venues = [
    'Bangalore', 'Delhi', 'Mumbai', 'Kolkata', 'Hyderabad', 'Chennai',
    'Jaipur', 'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
    'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
    'Ahmedabad', 'Cuttack', 'Nagpur', 'Visakhapatnam', 'Pune',
    'Raipur', 'Ranchi', 'Abu Dhabi', 'Bengaluru', 'Dubai',
    'Sharjah', 'Navi Mumbai', 'Chandigarh', 'Lucknow', 'Guwahati',
    'Dharamsala', 'Mohali'
]

# Dictionary for team colors
team_colors = {
    'Mumbai Indians': '#004BA0',  # Blue
    'Kolkata Knight Riders': '#3A225D',  # Purple
    'Rajasthan Royals': '#EA1A8E',  # Pink
    'Chennai Super Kings': '#FFFF00',  # Yellow
    'Sunrisers Hyderabad': '#FF822A',  # Orange
    'Delhi Capitals': '#17448A',  # Dark Blue
    'Punjab Kings': '#D71920',  # Red
    'Lucknow Super Giants': '#00A651',  # Green
    'Gujarat Titans': '#1C1C1C',  # Dark Grey
    'Royal Challengers Bengaluru': '#DA1D37',  # Red
}

# Dictionary for team abbreviations
team_abbr = {
    'Mumbai Indians': 'MI',
    'Kolkata Knight Riders': 'KKR',
    'Rajasthan Royals': 'RR',
    'Chennai Super Kings': 'CSK',
    'Sunrisers Hyderabad': 'SRH',
    'Delhi Capitals': 'DC',
    'Punjab Kings': 'PBKS',
    'Lucknow Super Giants': 'LSG',
    'Gujarat Titans': 'GT',
    'Royal Challengers Bengaluru': 'RCB'
}

# Custom CSS for styling
st.markdown(
    """
    <style>
    .main {
        background-color: #1E1E1E;
        border-radius: 15px;
        padding: 10px;
    }
    .prediction {
        font-size: 24px;
        font-weight: bold;
        color: white;
        text-align: center;
        margin-top: 20px;
    }
    .button {
        display: flex;
        justify-content: center;
        margin-top: 10px;
    }
    .stButton button {
        background-color: #007bff;
        color: white;
        border-radius: 8px;
        padding: 10px 30px;
        font-size: 20px;
    }
    </style>
    """,
    unsafe_allow_html=True,
)

# Main title
st.title("Predict - IPL Match Prediction App")

# Layout for team and venue selection
col1, col2 = st.columns(2)
with col1:
    batting_team = st.selectbox("Select the Batting Team", sorted(teams))
with col2:
    bowling_team = st.selectbox("Select the Bowling Team", sorted(teams))

venue = st.selectbox("Select Venue", sorted(venues))

# Target and match details
target = st.number_input("Target")
col3, col4, col5 = st.columns(3)
with col3:
    score = st.number_input("Score")
with col4:
    overs = st.number_input("Overs completed")
with col5:
    wickets = st.number_input("Wickets out")

# Predict button
if st.button('Predict'):
    runs_left = target - score
    balls_left = 120 - (overs * 6)
    wickets_left = 10 - wickets
    crr = score / overs if overs > 0 else 0
    rr = (runs_left * 6) / balls_left if balls_left > 0 else 0

    input_df = pd.DataFrame({
        'batting_team': [batting_team], 'bowling_team': [bowling_team],
        'city': [venue], 'runs_left': [runs_left], 'balls_left': [balls_left],
        'wickets_left': [wickets_left], 'total_runs_x': [target],
        'crr': [crr], 'rr': [rr]
    })

    result = pipe.predict_proba(input_df)
    loss = result[0][0]
    win = result[0][1]

    # Get team colors and abbreviations
    batting_color = team_colors.get(batting_team, '#FFFFFF')  # Default to white if not found
    bowling_color = team_colors.get(bowling_team, '#FFFFFF')  # Default to white if not found
    batting_abbr = team_abbr.get(batting_team, 'Batting')
    bowling_abbr = team_abbr.get(bowling_team, 'Bowling')

    # Display the prediction result as text
    st.markdown("<div class='prediction'>{}</div>".format(
        f"{batting_team}: {round(win * 100)}% chance to win"
    ), unsafe_allow_html=True)
    st.markdown("<div class='prediction'>{}</div>".format(
        f"{bowling_team}: {round(loss * 100)}% chance to win"
    ), unsafe_allow_html=True)

    # Plotting stacked horizontal bar chart for win and loss probabilities
    fig, ax = plt.subplots(figsize=(10, 3))  # Adjusted figure size
    ax.barh([f'{batting_abbr} vs {bowling_abbr}'], [win * 100], color=batting_color)  # Color for batting team
    ax.barh([f'{batting_abbr} vs {bowling_abbr}'], [loss * 100], left=[win * 100], color=bowling_color)  # Color for bowling team

    # Remove the axes and spines
    ax.axis('off')

    # Set the background color to match the app's dark theme
    fig.patch.set_facecolor('#1E1E1E')  # Background color of the entire figure
    ax.set_facecolor('#1E1E1E')  # Background color of the plot area

    # Adding percentage text to the bar chart
    ax.text(win * 50, 0, f'{batting_abbr}: {int(win * 100)}%', va='center', ha='center', color='white', fontsize=12)
    ax.text(100 - (loss * 50), 0, f'{bowling_abbr}: {int(loss * 100)}%', va='center', ha='center', color='white', fontsize=12)

    st.pyplot(fig)

# Add some space at the bottom
st.markdown("<div class='button'></div>", unsafe_allow_html=True)
# Out:
# Overwriting app.py

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.69.132.60

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.69.132.60:8501
#
# your url is: https://silent-peas-kick.loca.lt
#   Stopping...
# ^C
